# %% [markdown]
# #Step 1: Setting up the Environment

# %%
# !pip install torch torchvision
# !pip install transformers
# !pip install huggingface_hub
# !pip install datasets
# Out:
# Requirement already satisfied: torch in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: torchvision in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (0.17.2)
# Requirement already satisfied: filelock in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: transformers in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (4.40.2)
# Requirement already satisfied: filelock in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from transformers) (0.23.0)
# Requirement already satisfied: numpy>=1.17 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from transformers) (2024.5.10)
# Requirement already satisfied: requests in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: huggingface_hub in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (0.23.0)
# Requirement already satisfied: filelock in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from huggingface_hub) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from huggingface_hub) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from huggingface_hub) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from huggingface_hub) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from requests->huggingface_hub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from requests->huggingface_hub) (2024.2.2)
# Requirement already satisfied: datasets in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (2.19.1)
# Requirement already satisfied: filelock in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from datasets) (16.0.0)
# Requirement already satisfied: pyarrow-hotfix in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from datasets) (4.66.4)
# Requirement already satisfied: xxhash in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from datasets) (0.23.0)
# Requirement already satisfied: packaging in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from pandas->datasets) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/tashapais/mambaforge/envs/your_env_name/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import transforms, models
from torchvision.datasets import ImageFolder
from torchvision.transforms import Compose, Resize, ToTensor, Normalize

# %%
# Define transformations
transform = Compose([
    Resize((224, 224)),  # Resize images to 224x224
    ToTensor(),  # Convert images to tensor
    Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize images
])

# Setup the ImageNet dataset
imagenet_data = ImageFolder(root='/Users/tashapais/Downloads/imagenet-1k/train/', transform=transform)

# Setup the DataLoader
train_loader = DataLoader(imagenet_data, batch_size=32, shuffle=True, num_workers=4)

# %%
class VimBlock(nn.Module):
    def __init__(self, D, M, N, E):
        super(VimBlock, self).__init__()
        self.norm = nn.LayerNorm(D)
        self.linear1 = nn.Linear(D, M)
        self.linear2 = nn.Linear(M, E)
        self.conv1d = nn.Conv1d(E, N, kernel_size=3, padding=1)
        self.silu = nn.SiLU()
        self.linearA = nn.Linear(N, M)
        self.linearB = nn.Linear(N, N)
        self.linearC = nn.Linear(N, E)
        self.softmax = nn.Softmax(dim=-1)
        self.parameterA = nn.Parameter(torch.randn(E, N))

    def forward(self, x):
        x = self.norm(x)
        x = self.linear1(x)
        x = self.linear2(x)

        # Ensure x is [batch, E] at this point
        x = x.unsqueeze(2)  # Change shape to [batch, E, 1]
        
        # Duplicate the last dimension (length) to simulate bidirectional processing
        x = torch.cat([x, x], dim=2)  # Now x is [batch, E, 2]

        # Now x is [batch, E, 2], make sure to permute dimensions for Conv1d
        x = x.permute(0, 2, 1)  # Correctly rearrange to [batch, 2, E]

        x = self.conv1d(x.permute(0, 2, 1))  # Rearrange to [batch, E, 2] for Conv1d
        x = self.silu(x)
        
        A = self.linearA(x)
        B = self.linearB(x)
        C = self.linearC(x)
        
        delta_o = self.softmax(A + self.parameterA.unsqueeze(0))
        B = delta_o * B
        
        return C * (A + B)

# Test the model to confirm the changes
model = VimBlock(D=224, M=1024, N=512, E=256)
x = torch.rand(10, 224)  # Example input tensor
output = model(x)
print("Output shape:", output.shape)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/tashapais/Downloads/tasha_report.ipynb Cell 5 line 4
#      <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X21sZmlsZQ%3D%3D?line=41'>42</a> model = VimBlock(D=224, M=1024, N=512, E=256)
#      <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X21sZmlsZQ%3D%3D?line=42'>43</a> x = torch.rand(10, 224)  # Example input tensor
# ---> <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X21sZmlsZQ%3D%3D?line=43'>44</a> output = model(x)
#      <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X21sZmlsZQ%3D%3D?line=44'>45</a> print("Output shape:", output.shape)
#
# File ~/mambaforge/envs/your_env_name/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/mambaforge/envs/your_env_name/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# /Users/tashapais/Downloads/tasha_report.ipynb Cell 5 line 3
#      <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X21sZmlsZQ%3D%3D?line=28'>29</a> x = self.conv1d(x.permute(0, 2, 1))  # Rearrange to [batch, E, 2] for Conv1d
#      <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X21sZmlsZQ%3D%3D?line=29'>30</a> x = self.silu(x)
# ---> <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X21sZmlsZQ%3D%3D?line=31'>32</a> A = self.linearA(x)
#      <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X21sZmlsZQ%3D%3D?line=32'>33</a> B = self.linearB(x)
#      <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X21sZmlsZQ%3D%3D?line=33'>34</a> C = self.linearC(x)
#
# File ~/mambaforge/envs/your_env_name/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/mambaforge/envs/your_env_name/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/mambaforge/envs/your_env_name/lib/python3.10/site-packages/torch/nn/modules/linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (5120x2 and 512x1024)

# %%
# Step 5: Training Setup
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
train_loader = DataLoader(imagenet_data, batch_size=32, shuffle=True)

def train_epoch(model, train_loader, criterion, optimizer):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    return running_loss / len(train_loader)

# %%
# Step 6: Train the Model
for epoch in range(10):  # Adjust the number of epochs as needed
    loss = train_epoch(model, train_loader, criterion, optimizer)
    print(f"Epoch {epoch+1}, Loss: {loss}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/tashapais/Downloads/tasha_report.ipynb Cell 7 line 3
#       <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> # Step 6: Train the Model
#       <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> for epoch in range(10):  # Adjust the number of epochs as needed
# ----> <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>     loss = train_epoch(model, train_loader, criterion, optimizer)
#       <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a>     print(f"Epoch {epoch+1}, Loss: {loss}")
#
# /Users/tashapais/Downloads/tasha_report.ipynb Cell 7 line 1
#       <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X23sZmlsZQ%3D%3D?line=8'>9</a> for images, labels in train_loader:
#      <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X23sZmlsZQ%3D%3D?line=9'>10</a>     optimizer.zero_grad()
# ---> <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X23sZmlsZQ%3D%3D?line=10'>11</a>     outputs = model(images)
#      <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X23sZmlsZQ%3D%3D?line=11'>12</a>     loss = criterion(outputs, labels)
#      <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X23sZmlsZQ%3D%3D?line=12'>13</a>     loss.backward()
#
# File ~/mambaforge/envs/your_env_name/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/mambaforge/envs/your_env_name/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# /Users/tashapais/Downloads/tasha_report.ipynb Cell 7 line 2
#      <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X23sZmlsZQ%3D%3D?line=17'>18</a> x = self.linear1(x)
#      <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X23sZmlsZQ%3D%3D?line=18'>19</a> x = self.linear2(x)
# ---> <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X23sZmlsZQ%3D%3D?line=19'>20</a> x = x.unsqueeze(2).repeat(1, 1, 2)  # Simulating bidirectional processing
#      <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X23sZmlsZQ%3D%3D?line=20'>21</a> x = self.conv1d(x)
#      <a href='vscode-notebook-cell:/Users/tashapais/Downloads/tasha_report.ipynb#X23sZmlsZQ%3D%3D?line=21'>22</a> x = self.silu(x)
#
# RuntimeError: Number of dimensions of repeat dims can not be smaller than number of dimensions of tensor
